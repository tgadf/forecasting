# %% [markdown]
# # Basic Functions and Settings

# %%
# %load_ext autoreload
# %autoreload

#%autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))

import pandas as pd
pd.set_option("display.max_rows",1000)
pd.set_option("display.max_columns",500)
pd.set_option('precision', 3)

from os.path import join
from os import listdir
from pandas import read_csv, read_excel, Series, DataFrame, to_numeric, read_parquet, to_datetime, read_pickle
from pandas import date_range, concat
from sklearn.externals import joblib
from sklearn import metrics

import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})

import warnings
warnings.filterwarnings('ignore')

from pmdarima.arima import auto_arima
import tsfresh as tsf
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>

# %% [markdown]
# # ML Training Functions

# %%
def trainLogReg(X_train, y_train):
    name = 'logreg'
    glm = LogisticRegression()
    model = trainEstimator(name, glm, X_train, y_train)
    return model

def trainRF(X_train, y_train):
    name = 'rf'
    rf = RandomForestClassifier(n_estimators=50)
    model = trainEstimator(name, rf, X_train, y_train)
    return model

def trainXGboost(X_train, y_train):
    name = 'xgb'
    xgb = xgboost.XGBClassifier(n_jobs=1)
    model = trainEstimator(name, xgb, X_train, y_train)
    return model

# %%
def predAll(models, X_test):
    perfs = {}
    for modelname, model in models.items():
        y_probs  = model.predict_proba(X_test)[:,1]
        y_probs  = Series(data=y_probs, name="predicted")
        y_preds  = model.predict(X_test)
        y_preds  = Series(data=y_preds, name="predicted")
        perfs[modelname] = {"Probs": y_probs, "Preds": y_preds}
    return perfs
    
    
def trainAll(X_train, y_train):
    logreg = trainLogReg(X_train, y_train)
    rf     = trainRF(X_train, y_train)
    xgb    = trainXGboost(X_train, y_train)
    models = {"logreg": logreg, "xgb": xgb, "rf": rf}
    return models

def perfAll(perfs, y_test):
    modelperfdata = {}
    for modelname,modeldata in perfs.items():
        retval = {}
        y_truth = y_test
        y_probs = modeldata['Probs']
        y_preds = modeldata['Preds']
        precision, recall, pr_thresholds = precision_recall_curve(y_truth, y_probs)
        retval["PR"] = {"precision": precision, "recall": recall, "thresholds": pr_thresholds}

        fpr, tpr, roc_thresholds = roc_curve(y_truth, y_probs)
        retval["ROC"] = {"fpr": fpr, "tpr": tpr, "thresholds": roc_thresholds}

        auc = roc_auc_score(y_truth, y_probs)
        retval["AUC"] = auc

        cfm = confusion_matrix(y_truth, y_preds)
        tn, fp, fn, tp = cfm.ravel()
        retval["Confusion"] = {"matrix": cfm, "tn": tn, "tp": tp, "fn": fn, "fp": fp}

        modelperfdata[modelname] = retval
    return modelperfdata

# %% [markdown]
# # Load Data

# %%
def cutData(data, startYear):
    salesdata = data.copy()
    salesdata = salesdata[(salesdata.index <= to_datetime('2019-05-01')) & (salesdata.index >= to_datetime('{0}-01-01'.format(startYear)))]
    for colname in salesdata.columns:
        salesdata[colname] = salesdata[colname]/1000
    return salesdata

# %%
data["Date"].values
# Out:
# array(['2013-01-01', '2013-02-01', '2013-03-01', '2013-04-01',
#        '2013-05-01', '2013-06-01', '2013-07-01', '2013-08-01',
#        '2013-09-01', '2013-10-01', '2013-11-01', '2013-12-01',
#        '2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01',
#        '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01',
#        '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01',
#        '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#        '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01',
#        '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01',
#        '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01',
#        '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01',
#        '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01',
#        '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01',
#        '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01',
#        '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01',
#        '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#        '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#        '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01',
#        '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#        '2019-05-01'], dtype=object)

# %%
#data = read_pickle("Aggdata/TotalSales.p")
data = read_csv("Aggdata/TotalSales.csv")
data.columns = ["Date", "Total"]
data.index = to_datetime(data["Date"].values)
data.drop("Date", axis=1, inplace=True)
data["Total"] *= 1000
startYear = 2013
salesdata = cutData(data, startYear)
salesdata.head()
# Out:
#               Total
# 2013-01-01  211.842
# 2013-02-01  239.873
# 2013-03-01  189.759
# 2013-04-01  188.456
# 2013-05-01  242.191

# %% [markdown]
# # Feature Creation

# %%
##########################################################################################
## Data <-> Row Functions
##########################################################################################
def getPos(salesdata, currDate):
    try:
        ipos = salesdata.index.get_loc(currDate)
        return ipos
    except:
        raise ValueError("Date {0} not found!".format(currDate))
        return None
    
def getDateFromPos(salesdata, ipos):
    try:
        currDate = salesdata.index[ipos]
    except:
        raise ValueError("Date for position {0} doesn't exist".format(ipos))
    return currDate


##########################################################################################
## Window Functions
##########################################################################################
def getWindow(salesdata, currDate, entries):
    ipos = getPos(salesdata, currDate)
    if entries <= ipos:
        windowData = salesdata[(ipos-entries):ipos]
        return windowData
    else:
        #print("Not enough entries before {0}".format(currDate))
        return None
    
def getPrevYearWindow(salesdata, currDate, entries, years):
    pyData = {}
    ipos = getPos(salesdata, currDate)
    for iyear in range(1,years+1):
        iypos    = ipos - 12*iyear
        if iypos < 0:
            pyData[iyear] = None
            continue
        prevDate = getDateFromPos(salesdata, iypos)
        windowData = getWindow(salesdata, prevDate, entries)
        pyData[iyear] = windowData

    return pyData


##########################################################################################
## Window --> Number Function
##########################################################################################
def getWindowValue(window, valtype="avg"):
    if window is None:
        return None
    
    if valtype in ["mean", "avg"]:
        retval = window.mean()
    elif valtype in ["max"]:
        retval = window.max()
    elif valtype in ["min"]:
        retval = window.min()
    elif valtype in ["diff"]:
        retval = window.diff().mean()
    return float(retval.values)

def getMultiWindowValue(multiwindow, valtype="avg"):
    mvwin  = Series([getWindowValue(multiwindow[x], valtype) for x in reversed(list(multiwindow.keys()))])
    if len(multiwindow) == 1:
        retval = float(mvwin.mean())
    else:
        if sum([1 for x in mvwin.values if x is not None]) < 2:
            retval = None
        else:
            retval = float(mvwin.diff().mean())
    return retval


##########################################################################################
## Current Month Functions
##########################################################################################
def getCurrQuarter(salesdata, currDate):
    ipos = getPos(salesdata, currDate)
    currData = salesdata[ipos:(ipos+1)]
    quarter  = "Q{0}".format(currData.index.quarter[0])
    return quarter

def getCurrValue(salesdata, currDate):
    ipos = getPos(salesdata, currDate)
    currData = salesdata[ipos:(ipos+1)]
    return float(currData.values)

        
if getPos(salesdata, salesdata.index[12]) != 12:
    raise ValueError("getPos() doesn't work")

# %%
win = getWindow(salesdata, '2019-05-01', 3)
win

# %%
valtype = "avg"
multiwindow = getPrevYearWindow(salesdata, '2019-05-01', 3, 3)
mvwin  = Series([getWindowValue(multiwindow[x], valtype) for x in reversed(list(multiwindow.keys()))])

sum([1 for x in pwin.values() if x is not None]) < 2

# %%
qrtr = getCurrQuarter(salesdata, '2019-05-01')
qrtr

# %%
regdata = {}
for i,ts in enumerate(list(salesdata.index)):
    y = getCurrValue(salesdata, ts)
    win  = getWindow(salesdata, ts, 3)
    pwin = getPrevYearWindow(salesdata, ts, 3, 1)
    
    winval   = getWindowValue(win)
    mvwinval = getMultiWindowValue(pwin)
    
    quarter = getCurrQuarter(salesdata, ts)
    
    mondata = {"Y": y, "Quarter": quarter, "PrevMonths": winval, "PrevYears": mvwinval}
    regdata[ts] = mondata
    #print(i,'\t',ts,'\t',y,'\t',winval,'\t',mvwinval)
    
DataFrame(regdata).T

# %%
pwin = getPrevYearWindow(salesdata, '2016-01-01', 3, 1)

# %%
pwin

# %%
win.diff().mean()

# %%
vtypes = ["mean", "min", "max", "diff"]
for vtype in vtypes:
    print(vtype,'\t',getWindowValue(win, vtype))

# %%
win.ewm(alpha=0.01).mean().mean()

# %%
tsfdata.dtypes

# %%
tsfdata = salesdata.reset_index(drop=True)
tsfdata["Time"] = range(len(salesdata.index))
tsfdata["ID"] = 1
tsfdata
# Out:
#       Total  Time  ID
# 0   211.842     0   1
# 1   239.873     1   1
# 2   189.759     2   1
# 3   188.456     3   1
# 4   242.191     4   1
# 5   202.538     5   1
# 6   219.153     6   1
# 7   211.684     7   1
# 8   221.814     8   1
# 9   311.817     9   1
# 10  215.931    10   1
# 11  199.922    11   1
# 12  257.488    12   1
# 13  215.066    13   1
# 14  184.515    14   1
# 15  256.350    15   1
# 16  272.665    16   1
# 17  214.411    17   1
# 18  226.209    18   1
# 19  231.554    19   1
# 20  309.343    20   1
# 21  283.008    21   1
# 22  213.098    22   1
# 23  205.024    23   1
# 24  216.598    24   1
# 25  173.004    25   1
# 26  236.185    26   1
# 27  249.400    27   1
# 28  265.968    28   1
# 29  229.358    29   1
# 30  267.641    30   1
# 31  246.528    31   1
# 32  336.414    32   1
# 33  292.202    33   1
# 34  266.172    34   1
# 35  194.756    35   1
# 36  247.310    36   1
# 37  220.729    37   1
# 38  175.332    38   1
# 39  239.440    39   1
# 40  291.780    40   1
# 41  228.679    41   1
# 42  260.009    42   1
# 43  246.362    43   1
# 44  335.626    44   1
# 45  307.211    45   1
# 46  208.629    46   1
# 47  193.047    47   1
# 48  280.599    48   1
# 49  227.198    49   1
# 50  192.878    50   1
# 51  271.660    51   1
# 52  331.622    52   1
# 53  217.649    53   1
# 54  253.876    54   1
# 55  296.047    55   1
# 56  300.249    56   1
# 57  276.417    57   1
# 58  249.814    58   1
# 59  194.644    59   1
# 60  291.258    60   1
# 61  230.726    61   1
# 62  204.205    62   1
# 63  320.265    63   1
# 64  348.158    64   1
# 65  237.794    65   1
# 66  271.357    66   1
# 67  306.908    67   1
# 68  282.998    68   1
# 69  297.158    69   1
# 70  261.155    70   1
# 71  227.467    71   1
# 72  279.975    72   1
# 73  225.664    73   1
# 74  254.895    74   1
# 75  260.299    75   1
# 76  294.924    76   1

# %%
#tsfdata = salesdata.reset_index(drop=True)
#tsfdata["Time"] = str(tsfdata.index)
#tsfdata["ID"] = 1
from tsfresh import extract_features
extracted_features = extract_features(tsfdata, column_id='ID')
# Out:
# Feature Extraction:   0%|          | 0/2 [00:00<?, ?it/s]
# Feature Extraction:  50%|█████     | 1/2 [00:00<00:00,  5.78it/s]
# Feature Extraction: 100%|██████████| 2/2 [00:00<00:00, 11.32it/s]

# %%
extracted_features.T
# Out:
# id                                                          1
# variable
# Time__abs_energy                                    1.492e+05
# Time__absolute_sum_of_changes                       7.600e+01
# Time__agg_autocorrelation__f_agg_"mean"__maxlag_40  2.807e-01
# Time__agg_autocorrelation__f_agg_"median"__maxl...  3.256e-01
# Time__agg_autocorrelation__f_agg_"var"__maxlag_40   2.128e-01
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  9.500e+00
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  9.993e-01
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  9.750e+00
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  1.443e-01
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  4.900e+01
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  1.000e+00
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  2.700e+01
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  0.000e+00
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  4.309e+00
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  9.996e-01
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  4.934e+00
# Time__agg_linear_trend__f_agg_"max"__chunk_len_...  3.821e-02
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  4.750e+00
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  9.998e-01
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  9.875e+00
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  7.217e-02
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  2.450e+01
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  1.000e+00
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  3.850e+01
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  0.000e+00
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  2.154e+00
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  9.999e-01
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  4.967e+00
# Time__agg_linear_trend__f_agg_"mean"__chunk_len...  1.910e-02
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  0.000e+00
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  1.000e+00
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  1.000e+01
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  0.000e+00
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  0.000e+00
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  1.000e+00
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  5.000e+01
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  0.000e+00
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  0.000e+00
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  1.000e+00
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  5.000e+00
# Time__agg_linear_trend__f_agg_"min"__chunk_len_...  0.000e+00
# Time__agg_linear_trend__f_agg_"var"__chunk_len_...  8.958e+00
# Time__agg_linear_trend__f_agg_"var"__chunk_len_... -5.774e-01
# Time__agg_linear_trend__f_agg_"var"__chunk_len_... -3.542e-01
# Time__agg_linear_trend__f_agg_"var"__chunk_len_...  2.045e-01
# Time__agg_linear_trend__f_agg_"var"__chunk_len_...  2.082e+02
# Time__agg_linear_trend__f_agg_"var"__chunk_len_... -1.000e+00
# Time__agg_linear_trend__f_agg_"var"__chunk_len_... -1.476e+02
# Time__agg_linear_trend__f_agg_"var"__chunk_len_...  0.000e+00
# Time__agg_linear_trend__f_agg_"var"__chunk_len_...  2.180e+00
# Time__agg_linear_trend__f_agg_"var"__chunk_len_... -4.201e-01
# Time__agg_linear_trend__f_agg_"var"__chunk_len_... -3.860e-02
# Time__agg_linear_trend__f_agg_"var"__chunk_len_...  2.229e-02
# Time__approximate_entropy__m_2__r_0.1               1.299e-02
# Time__approximate_entropy__m_2__r_0.3               1.255e-02
# Time__approximate_entropy__m_2__r_0.5               1.201e-02
# Time__approximate_entropy__m_2__r_0.7               1.158e-02
# Time__approximate_entropy__m_2__r_0.9               1.104e-02
# Time__ar_coefficient__k_10__coeff_0                 6.587e-02
# Time__ar_coefficient__k_10__coeff_1                 3.964e-01
# Time__ar_coefficient__k_10__coeff_2                 3.305e-01
# Time__ar_coefficient__k_10__coeff_3                 2.647e-01
# Time__ar_coefficient__k_10__coeff_4                 1.988e-01
# Time__augmented_dickey_fuller__attr_"pvalue"        1.000e+00
# Time__augmented_dickey_fuller__attr_"teststat"      7.875e+00
# Time__augmented_dickey_fuller__attr_"usedlag"       4.000e+00
# Time__autocorrelation__lag_0                        1.000e+00
# Time__autocorrelation__lag_1                        9.737e-01
# Time__autocorrelation__lag_2                        9.467e-01
# Time__autocorrelation__lag_3                        9.190e-01
# Time__autocorrelation__lag_4                        8.907e-01
# Time__autocorrelation__lag_5                        8.617e-01
# Time__autocorrelation__lag_6                        8.320e-01
# Time__autocorrelation__lag_7                        8.016e-01
# Time__autocorrelation__lag_8                        7.706e-01
# Time__autocorrelation__lag_9                        7.389e-01
# Time__binned_entropy__max_bins_10                   2.301e+00
# Time__c3__lag_1                                     1.083e+05
# Time__c3__lag_2                                     1.053e+05
# Time__c3__lag_3                                     1.024e+05
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Fal...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  0.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"mean"__isabs_Tru...  1.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_Fals...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__change_quantiles__f_agg_"var"__isabs_True...  0.000e+00
# Time__cid_ce__normalize_False                       8.718e+00
# Time__cid_ce__normalize_True                        3.922e-01
# Time__count_above_mean                              3.800e+01
# Time__count_below_mean                              3.800e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.719e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.426e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.035e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -9.680e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.631e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__...  3.466e-04
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__...  4.726e-01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.580e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.464e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__...  3.830e-04
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__...  3.418e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.056e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.301e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__...  4.195e-04
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__...  6.480e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -6.774e-01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.143e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__...  4.560e-04
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__...  9.645e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -4.173e-01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -9.935e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__...  4.925e-04
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__...  1.290e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.466e-01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.705e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.426e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.909e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -9.680e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.663e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.868e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.763e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -9.298e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.596e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.109e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.597e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -8.578e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.505e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -5.066e-01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.414e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -7.602e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.393e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.783e-01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.211e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -6.471e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.262e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -4.821e-02
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -9.915e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -5.290e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.117e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -9.847e-03
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -7.548e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -4.155e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.961e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.312e-03
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -5.022e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -3.134e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -1.798e+01
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__...  1.434e-04
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.344e+00
# Time__cwt_coefficients__widths_(2, 5, 10, 20)__... -2.270e+00
# Time__energy_ratio_by_chunks__num_segments_10__...  9.382e-04
# Time__energy_ratio_by_chunks__num_segments_10__...  7.371e-03
# Time__energy_ratio_by_chunks__num_segments_10__...  2.067e-02
# Time__energy_ratio_by_chunks__num_segments_10__...  4.082e-02
# Time__energy_ratio_by_chunks__num_segments_10__...  6.784e-02
# Time__energy_ratio_by_chunks__num_segments_10__...  1.017e-01
# Time__energy_ratio_by_chunks__num_segments_10__...  1.425e-01
# Time__energy_ratio_by_chunks__num_segments_10__...  1.635e-01
# Time__energy_ratio_by_chunks__num_segments_10__...  2.045e-01
# Time__energy_ratio_by_chunks__num_segments_10__...  2.502e-01
# Time__fft_aggregated__aggtype_"centroid"            5.865e+00
# Time__fft_aggregated__aggtype_"kurtosis"            5.875e+00
# Time__fft_aggregated__aggtype_"skew"                1.846e+00
# Time__fft_aggregated__aggtype_"variance"            8.841e+01
# Time__fft_coefficient__coeff_0__attr_"abs"          2.926e+03
# Time__fft_coefficient__coeff_0__attr_"angle"        0.000e+00
# Time__fft_coefficient__coeff_0__attr_"imag"         0.000e+00
# Time__fft_coefficient__coeff_0__attr_"real"         2.926e+03
# Time__fft_coefficient__coeff_10__attr_"abs"         9.703e+01
# Time__fft_coefficient__coeff_10__attr_"angle"       1.134e+02
# Time__fft_coefficient__coeff_10__attr_"imag"        8.907e+01
# Time__fft_coefficient__coeff_10__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_11__attr_"abs"         8.873e+01
# Time__fft_coefficient__coeff_11__attr_"angle"       1.157e+02
# Time__fft_coefficient__coeff_11__attr_"imag"        7.995e+01
# Time__fft_coefficient__coeff_11__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_12__attr_"abs"         8.187e+01
# Time__fft_coefficient__coeff_12__attr_"angle"       1.181e+02
# Time__fft_coefficient__coeff_12__attr_"imag"        7.225e+01
# Time__fft_coefficient__coeff_12__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_13__attr_"abs"         7.611e+01
# Time__fft_coefficient__coeff_13__attr_"angle"       1.204e+02
# Time__fft_coefficient__coeff_13__attr_"imag"        6.565e+01
# Time__fft_coefficient__coeff_13__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_14__attr_"abs"         7.121e+01
# Time__fft_coefficient__coeff_14__attr_"angle"       1.227e+02
# Time__fft_coefficient__coeff_14__attr_"imag"        5.991e+01
# Time__fft_coefficient__coeff_14__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_15__attr_"abs"         6.701e+01
# Time__fft_coefficient__coeff_15__attr_"angle"       1.251e+02
# Time__fft_coefficient__coeff_15__attr_"imag"        5.485e+01
# Time__fft_coefficient__coeff_15__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_16__attr_"abs"         6.338e+01
# Time__fft_coefficient__coeff_16__attr_"angle"       1.274e+02
# Time__fft_coefficient__coeff_16__attr_"imag"        5.035e+01
# Time__fft_coefficient__coeff_16__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_17__attr_"abs"         6.022e+01
# Time__fft_coefficient__coeff_17__attr_"angle"       1.297e+02
# Time__fft_coefficient__coeff_17__attr_"imag"        4.631e+01
# Time__fft_coefficient__coeff_17__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_18__attr_"abs"         5.745e+01
# Time__fft_coefficient__coeff_18__attr_"angle"       1.321e+02
# Time__fft_coefficient__coeff_18__attr_"imag"        4.264e+01
# Time__fft_coefficient__coeff_18__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_19__attr_"abs"         5.501e+01
# Time__fft_coefficient__coeff_19__attr_"angle"       1.344e+02
# Time__fft_coefficient__coeff_19__attr_"imag"        3.929e+01
# Time__fft_coefficient__coeff_19__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_1__attr_"abs"          9.439e+02
# Time__fft_coefficient__coeff_1__attr_"angle"        9.234e+01
# Time__fft_coefficient__coeff_1__attr_"imag"         9.431e+02
# Time__fft_coefficient__coeff_1__attr_"real"        -3.850e+01
# Time__fft_coefficient__coeff_20__attr_"abs"         5.285e+01
# Time__fft_coefficient__coeff_20__attr_"angle"       1.368e+02
# Time__fft_coefficient__coeff_20__attr_"imag"        3.621e+01
# Time__fft_coefficient__coeff_20__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_21__attr_"abs"         5.094e+01
# Time__fft_coefficient__coeff_21__attr_"angle"       1.391e+02
# Time__fft_coefficient__coeff_21__attr_"imag"        3.336e+01
# Time__fft_coefficient__coeff_21__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_22__attr_"abs"         4.924e+01
# Time__fft_coefficient__coeff_22__attr_"angle"       1.414e+02
# Time__fft_coefficient__coeff_22__attr_"imag"        3.070e+01
# Time__fft_coefficient__coeff_22__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_23__attr_"abs"         4.773e+01
# Time__fft_coefficient__coeff_23__attr_"angle"       1.438e+02
# Time__fft_coefficient__coeff_23__attr_"imag"        2.821e+01
# Time__fft_coefficient__coeff_23__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_24__attr_"abs"         4.638e+01
# Time__fft_coefficient__coeff_24__attr_"angle"       1.461e+02
# Time__fft_coefficient__coeff_24__attr_"imag"        2.587e+01
# Time__fft_coefficient__coeff_24__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_25__attr_"abs"         4.518e+01
# Time__fft_coefficient__coeff_25__attr_"angle"       1.484e+02
# Time__fft_coefficient__coeff_25__attr_"imag"        2.365e+01
# Time__fft_coefficient__coeff_25__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_26__attr_"abs"         4.411e+01
# Time__fft_coefficient__coeff_26__attr_"angle"       1.508e+02
# Time__fft_coefficient__coeff_26__attr_"imag"        2.154e+01
# Time__fft_coefficient__coeff_26__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_27__attr_"abs"         4.316e+01
# Time__fft_coefficient__coeff_27__attr_"angle"       1.531e+02
# Time__fft_coefficient__coeff_27__attr_"imag"        1.952e+01
# Time__fft_coefficient__coeff_27__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_28__attr_"abs"         4.232e+01
# Time__fft_coefficient__coeff_28__attr_"angle"       1.555e+02
# Time__fft_coefficient__coeff_28__attr_"imag"        1.758e+01
# Time__fft_coefficient__coeff_28__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_29__attr_"abs"         4.158e+01
# Time__fft_coefficient__coeff_29__attr_"angle"       1.578e+02
# Time__fft_coefficient__coeff_29__attr_"imag"        1.572e+01
# Time__fft_coefficient__coeff_29__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_2__attr_"abs"          4.723e+02
# Time__fft_coefficient__coeff_2__attr_"angle"        9.468e+01
# Time__fft_coefficient__coeff_2__attr_"imag"         4.708e+02
# Time__fft_coefficient__coeff_2__attr_"real"        -3.850e+01
# Time__fft_coefficient__coeff_30__attr_"abs"         4.094e+01
# Time__fft_coefficient__coeff_30__attr_"angle"       1.601e+02
# Time__fft_coefficient__coeff_30__attr_"imag"        1.391e+01
# Time__fft_coefficient__coeff_30__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_31__attr_"abs"         4.038e+01
# Time__fft_coefficient__coeff_31__attr_"angle"       1.625e+02
# Time__fft_coefficient__coeff_31__attr_"imag"        1.216e+01
# Time__fft_coefficient__coeff_31__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_32__attr_"abs"         3.989e+01
# Time__fft_coefficient__coeff_32__attr_"angle"       1.648e+02
# Time__fft_coefficient__coeff_32__attr_"imag"        1.046e+01
# Time__fft_coefficient__coeff_32__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_33__attr_"abs"         3.949e+01
# Time__fft_coefficient__coeff_33__attr_"angle"       1.671e+02
# Time__fft_coefficient__coeff_33__attr_"imag"        8.787e+00
# Time__fft_coefficient__coeff_33__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_34__attr_"abs"         3.916e+01
# Time__fft_coefficient__coeff_34__attr_"angle"       1.695e+02
# Time__fft_coefficient__coeff_34__attr_"imag"        7.149e+00
# Time__fft_coefficient__coeff_34__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_35__attr_"abs"         3.890e+01
# Time__fft_coefficient__coeff_35__attr_"angle"       1.718e+02
# Time__fft_coefficient__coeff_35__attr_"imag"        5.535e+00
# Time__fft_coefficient__coeff_35__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_36__attr_"abs"         3.870e+01
# Time__fft_coefficient__coeff_36__attr_"angle"       1.742e+02
# Time__fft_coefficient__coeff_36__attr_"imag"        3.941e+00
# Time__fft_coefficient__coeff_36__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_37__attr_"abs"         3.857e+01
# Time__fft_coefficient__coeff_37__attr_"angle"       1.765e+02
# Time__fft_coefficient__coeff_37__attr_"imag"        2.359e+00
# Time__fft_coefficient__coeff_37__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_38__attr_"abs"         3.851e+01
# Time__fft_coefficient__coeff_38__attr_"angle"       1.788e+02
# Time__fft_coefficient__coeff_38__attr_"imag"        7.855e-01
# Time__fft_coefficient__coeff_38__attr_"real"       -3.850e+01
# Time__fft_coefficient__coeff_39__attr_"abs"               NaN
# Time__fft_coefficient__coeff_39__attr_"angle"             NaN
# Time__fft_coefficient__coeff_39__attr_"imag"              NaN
# Time__fft_coefficient__coeff_39__attr_"real"              NaN
# Time__fft_coefficient__coeff_3__attr_"abs"          3.153e+02
# Time__fft_coefficient__coeff_3__attr_"angle"        9.701e+01
# Time__fft_coefficient__coeff_3__attr_"imag"         3.130e+02
# Time__fft_coefficient__coeff_3__attr_"real"        -3.850e+01
# Time__fft_coefficient__coeff_40__attr_"abs"               NaN
# Time__fft_coefficient__coeff_40__attr_"angle"             NaN
# Time__fft_coefficient__coeff_40__attr_"imag"              NaN
# Time__fft_coefficient__coeff_40__attr_"real"              NaN
# Time__fft_coefficient__coeff_41__attr_"abs"               NaN
# Time__fft_coefficient__coeff_41__attr_"angle"             NaN
# Time__fft_coefficient__coeff_41__attr_"imag"              NaN
# Time__fft_coefficient__coeff_41__attr_"real"              NaN
# Time__fft_coefficient__coeff_42__attr_"abs"               NaN
# Time__fft_coefficient__coeff_42__attr_"angle"             NaN
# Time__fft_coefficient__coeff_42__attr_"imag"              NaN
# Time__fft_coefficient__coeff_42__attr_"real"              NaN
# Time__fft_coefficient__coeff_43__attr_"abs"               NaN
# Time__fft_coefficient__coeff_43__attr_"angle"             NaN
# Time__fft_coefficient__coeff_43__attr_"imag"              NaN
# Time__fft_coefficient__coeff_43__attr_"real"              NaN
# Time__fft_coefficient__coeff_44__attr_"abs"               NaN
# Time__fft_coefficient__coeff_44__attr_"angle"             NaN
# Time__fft_coefficient__coeff_44__attr_"imag"              NaN
# Time__fft_coefficient__coeff_44__attr_"real"              NaN
# Time__fft_coefficient__coeff_45__attr_"abs"               NaN
# Time__fft_coefficient__coeff_45__attr_"angle"             NaN
# Time__fft_coefficient__coeff_45__attr_"imag"              NaN
# Time__fft_coefficient__coeff_45__attr_"real"              NaN
# Time__fft_coefficient__coeff_46__attr_"abs"               NaN
# Time__fft_coefficient__coeff_46__attr_"angle"             NaN
# Time__fft_coefficient__coeff_46__attr_"imag"              NaN
# Time__fft_coefficient__coeff_46__attr_"real"              NaN
# Time__fft_coefficient__coeff_47__attr_"abs"               NaN
# Time__fft_coefficient__coeff_47__attr_"angle"             NaN
# Time__fft_coefficient__coeff_47__attr_"imag"              NaN
# Time__fft_coefficient__coeff_47__attr_"real"              NaN
# Time__fft_coefficient__coeff_48__attr_"abs"               NaN
# Time__fft_coefficient__coeff_48__attr_"angle"             NaN
# Time__fft_coefficient__coeff_48__attr_"imag"              NaN
# Time__fft_coefficient__coeff_48__attr_"real"              NaN
# Time__fft_coefficient__coeff_49__attr_"abs"               NaN
# Time__fft_coefficient__coeff_49__attr_"angle"             NaN
# Time__fft_coefficient__coeff_49__attr_"imag"              NaN
# Time__fft_coefficient__coeff_49__attr_"real"              NaN
# Time__fft_coefficient__coeff_4__attr_"abs"          2.370e+02
# Time__fft_coefficient__coeff_4__attr_"angle"        9.935e+01
# Time__fft_coefficient__coeff_4__attr_"imag"         2.338e+02
# Time__fft_coefficient__coeff_4__attr_"real"        -3.850e+01
# Time__fft_coefficient__coeff_50__attr_"abs"               NaN
# Time__fft_coefficient__coeff_50__attr_"angle"             NaN
# Time__fft_coefficient__coeff_50__attr_"imag"              NaN
# Time__fft_coefficient__coeff_50__attr_"real"              NaN
# Time__fft_coefficient__coeff_51__attr_"abs"               NaN
# Time__fft_coefficient__coeff_51__attr_"angle"             NaN
# Time__fft_coefficient__coeff_51__attr_"imag"              NaN
# Time__fft_coefficient__coeff_51__attr_"real"              NaN
# Time__fft_coefficient__coeff_52__attr_"abs"               NaN
# Time__fft_coefficient__coeff_52__attr_"angle"             NaN
# Time__fft_coefficient__coeff_52__attr_"imag"              NaN
# Time__fft_coefficient__coeff_52__attr_"real"              NaN
# Time__fft_coefficient__coeff_53__attr_"abs"               NaN
# Time__fft_coefficient__coeff_53__attr_"angle"             NaN
# Time__fft_coefficient__coeff_53__attr_"imag"              NaN
# Time__fft_coefficient__coeff_53__attr_"real"              NaN
# Time__fft_coefficient__coeff_54__attr_"abs"               NaN
# Time__fft_coefficient__coeff_54__attr_"angle"             NaN
# Time__fft_coefficient__coeff_54__attr_"imag"              NaN
# Time__fft_coefficient__coeff_54__attr_"real"              NaN
# Time__fft_coefficient__coeff_55__attr_"abs"               NaN
# Time__fft_coefficient__coeff_55__attr_"angle"             NaN
# Time__fft_coefficient__coeff_55__attr_"imag"              NaN
# Time__fft_coefficient__coeff_55__attr_"real"              NaN
# Time__fft_coefficient__coeff_56__attr_"abs"               NaN
# Time__fft_coefficient__coeff_56__attr_"angle"             NaN
# Time__fft_coefficient__coeff_56__attr_"imag"              NaN
# Time__fft_coefficient__coeff_56__attr_"real"              NaN
# Time__fft_coefficient__coeff_57__attr_"abs"               NaN
# Time__fft_coefficient__coeff_57__attr_"angle"             NaN
# Time__fft_coefficient__coeff_57__attr_"imag"              NaN
# Time__fft_coefficient__coeff_57__attr_"real"              NaN
# Time__fft_coefficient__coeff_58__attr_"abs"               NaN
# Time__fft_coefficient__coeff_58__attr_"angle"             NaN
# Time__fft_coefficient__coeff_58__attr_"imag"              NaN
# Time__fft_coefficient__coeff_58__attr_"real"              NaN
# Time__fft_coefficient__coeff_59__attr_"abs"               NaN
# Time__fft_coefficient__coeff_59__attr_"angle"             NaN
# Time__fft_coefficient__coeff_59__attr_"imag"              NaN
# Time__fft_coefficient__coeff_59__attr_"real"              NaN
# Time__fft_coefficient__coeff_5__attr_"abs"          1.900e+02
# Time__fft_coefficient__coeff_5__attr_"angle"        1.017e+02
# Time__fft_coefficient__coeff_5__attr_"imag"         1.861e+02
# Time__fft_coefficient__coeff_5__attr_"real"        -3.850e+01
# Time__fft_coefficient__coeff_60__attr_"abs"               NaN
# Time__fft_coefficient__coeff_60__attr_"angle"             NaN
# Time__fft_coefficient__coeff_60__attr_"imag"              NaN
# Time__fft_coefficient__coeff_60__attr_"real"              NaN
# Time__fft_coefficient__coeff_61__attr_"abs"               NaN
# Time__fft_coefficient__coeff_61__attr_"angle"             NaN
# Time__fft_coefficient__coeff_61__attr_"imag"              NaN
# Time__fft_coefficient__coeff_61__attr_"real"              NaN
# Time__fft_coefficient__coeff_62__attr_"abs"               NaN
# Time__fft_coefficient__coeff_62__attr_"angle"             NaN
# Time__fft_coefficient__coeff_62__attr_"imag"              NaN
# Time__fft_coefficient__coeff_62__attr_"real"              NaN
# Time__fft_coefficient__coeff_63__attr_"abs"               NaN
# Time__fft_coefficient__coeff_63__attr_"angle"             NaN
# Time__fft_coefficient__coeff_63__attr_"imag"              NaN
# Time__fft_coefficient__coeff_63__attr_"real"              NaN
# Time__fft_coefficient__coeff_64__attr_"abs"               NaN
# Time__fft_coefficient__coeff_64__attr_"angle"             NaN
# ...                                                       ...
# Total__fft_coefficient__coeff_18__attr_"abs"        1.464e+02
# Total__fft_coefficient__coeff_18__attr_"angle"     -3.170e+00
# Total__fft_coefficient__coeff_18__attr_"imag"      -8.094e+00
# Total__fft_coefficient__coeff_18__attr_"real"       1.462e+02
# Total__fft_coefficient__coeff_19__attr_"abs"        8.229e+02
# Total__fft_coefficient__coeff_19__attr_"angle"      4.523e+01
# Total__fft_coefficient__coeff_19__attr_"imag"       5.841e+02
# Total__fft_coefficient__coeff_19__attr_"real"       5.796e+02
# Total__fft_coefficient__coeff_1__attr_"abs"         6.451e+02
# Total__fft_coefficient__coeff_1__attr_"angle"       1.018e+02
# Total__fft_coefficient__coeff_1__attr_"imag"        6.316e+02
# Total__fft_coefficient__coeff_1__attr_"real"       -1.315e+02
# Total__fft_coefficient__coeff_20__attr_"abs"        6.733e+02
# Total__fft_coefficient__coeff_20__attr_"angle"     -1.538e+02
# Total__fft_coefficient__coeff_20__attr_"imag"      -2.972e+02
# Total__fft_coefficient__coeff_20__attr_"real"      -6.041e+02
# Total__fft_coefficient__coeff_21__attr_"abs"        4.333e+02
# Total__fft_coefficient__coeff_21__attr_"angle"     -9.444e+01
# Total__fft_coefficient__coeff_21__attr_"imag"      -4.320e+02
# Total__fft_coefficient__coeff_21__attr_"real"      -3.353e+01
# Total__fft_coefficient__coeff_22__attr_"abs"        2.728e+02
# Total__fft_coefficient__coeff_22__attr_"angle"      1.539e+02
# Total__fft_coefficient__coeff_22__attr_"imag"       1.202e+02
# Total__fft_coefficient__coeff_22__attr_"real"      -2.449e+02
# Total__fft_coefficient__coeff_23__attr_"abs"        1.008e+02
# Total__fft_coefficient__coeff_23__attr_"angle"      7.412e+01
# Total__fft_coefficient__coeff_23__attr_"imag"       9.697e+01
# Total__fft_coefficient__coeff_23__attr_"real"       2.759e+01
# Total__fft_coefficient__coeff_24__attr_"abs"        2.171e+02
# Total__fft_coefficient__coeff_24__attr_"angle"      3.746e+01
# Total__fft_coefficient__coeff_24__attr_"imag"       1.321e+02
# Total__fft_coefficient__coeff_24__attr_"real"       1.724e+02
# Total__fft_coefficient__coeff_25__attr_"abs"        5.244e+02
# Total__fft_coefficient__coeff_25__attr_"angle"      1.134e+02
# Total__fft_coefficient__coeff_25__attr_"imag"       4.814e+02
# Total__fft_coefficient__coeff_25__attr_"real"      -2.080e+02
# Total__fft_coefficient__coeff_26__attr_"abs"        5.239e+02
# Total__fft_coefficient__coeff_26__attr_"angle"     -1.069e+02
# Total__fft_coefficient__coeff_26__attr_"imag"      -5.012e+02
# Total__fft_coefficient__coeff_26__attr_"real"      -1.527e+02
# Total__fft_coefficient__coeff_27__attr_"abs"        4.485e+02
# Total__fft_coefficient__coeff_27__attr_"angle"     -8.524e+01
# Total__fft_coefficient__coeff_27__attr_"imag"      -4.470e+02
# Total__fft_coefficient__coeff_27__attr_"real"       3.724e+01
# Total__fft_coefficient__coeff_28__attr_"abs"        2.501e+02
# Total__fft_coefficient__coeff_28__attr_"angle"     -1.237e+02
# Total__fft_coefficient__coeff_28__attr_"imag"      -2.080e+02
# Total__fft_coefficient__coeff_28__attr_"real"      -1.389e+02
# Total__fft_coefficient__coeff_29__attr_"abs"        1.857e+02
# Total__fft_coefficient__coeff_29__attr_"angle"      1.054e+02
# Total__fft_coefficient__coeff_29__attr_"imag"       1.790e+02
# Total__fft_coefficient__coeff_29__attr_"real"      -4.929e+01
# Total__fft_coefficient__coeff_2__attr_"abs"         4.376e+02
# Total__fft_coefficient__coeff_2__attr_"angle"       1.104e+02
# Total__fft_coefficient__coeff_2__attr_"imag"        4.100e+02
# Total__fft_coefficient__coeff_2__attr_"real"       -1.528e+02
# Total__fft_coefficient__coeff_30__attr_"abs"        1.707e+02
# Total__fft_coefficient__coeff_30__attr_"angle"     -1.640e+02
# Total__fft_coefficient__coeff_30__attr_"imag"      -4.700e+01
# Total__fft_coefficient__coeff_30__attr_"real"      -1.641e+02
# Total__fft_coefficient__coeff_31__attr_"abs"        1.523e+02
# Total__fft_coefficient__coeff_31__attr_"angle"      8.920e+01
# Total__fft_coefficient__coeff_31__attr_"imag"       1.523e+02
# Total__fft_coefficient__coeff_31__attr_"real"       2.118e+00
# Total__fft_coefficient__coeff_32__attr_"abs"        1.931e+02
# Total__fft_coefficient__coeff_32__attr_"angle"      1.464e+02
# Total__fft_coefficient__coeff_32__attr_"imag"       1.068e+02
# Total__fft_coefficient__coeff_32__attr_"real"      -1.608e+02
# Total__fft_coefficient__coeff_33__attr_"abs"        2.623e+02
# Total__fft_coefficient__coeff_33__attr_"angle"      8.746e+01
# Total__fft_coefficient__coeff_33__attr_"imag"       2.620e+02
# Total__fft_coefficient__coeff_33__attr_"real"       1.163e+01
# Total__fft_coefficient__coeff_34__attr_"abs"        9.224e+01
# Total__fft_coefficient__coeff_34__attr_"angle"      1.249e+02
# Total__fft_coefficient__coeff_34__attr_"imag"       7.566e+01
# Total__fft_coefficient__coeff_34__attr_"real"      -5.276e+01
# Total__fft_coefficient__coeff_35__attr_"abs"        1.179e+02
# Total__fft_coefficient__coeff_35__attr_"angle"      1.462e+02
# Total__fft_coefficient__coeff_35__attr_"imag"       6.550e+01
# Total__fft_coefficient__coeff_35__attr_"real"      -9.799e+01
# Total__fft_coefficient__coeff_36__attr_"abs"        4.719e+01
# Total__fft_coefficient__coeff_36__attr_"angle"     -7.526e+01
# Total__fft_coefficient__coeff_36__attr_"imag"      -4.563e+01
# Total__fft_coefficient__coeff_36__attr_"real"       1.200e+01
# Total__fft_coefficient__coeff_37__attr_"abs"        1.669e+02
# Total__fft_coefficient__coeff_37__attr_"angle"     -1.586e+02
# Total__fft_coefficient__coeff_37__attr_"imag"      -6.082e+01
# Total__fft_coefficient__coeff_37__attr_"real"      -1.554e+02
# Total__fft_coefficient__coeff_38__attr_"abs"        4.695e+02
# Total__fft_coefficient__coeff_38__attr_"angle"      1.110e+02
# Total__fft_coefficient__coeff_38__attr_"imag"       4.382e+02
# Total__fft_coefficient__coeff_38__attr_"real"      -1.684e+02
# Total__fft_coefficient__coeff_39__attr_"abs"              NaN
# Total__fft_coefficient__coeff_39__attr_"angle"            NaN
# Total__fft_coefficient__coeff_39__attr_"imag"             NaN
# Total__fft_coefficient__coeff_39__attr_"real"             NaN
# Total__fft_coefficient__coeff_3__attr_"abs"         2.553e+02
# Total__fft_coefficient__coeff_3__attr_"angle"       1.411e+02
# Total__fft_coefficient__coeff_3__attr_"imag"        1.604e+02
# Total__fft_coefficient__coeff_3__attr_"real"       -1.986e+02
# Total__fft_coefficient__coeff_40__attr_"abs"              NaN
# Total__fft_coefficient__coeff_40__attr_"angle"            NaN
# Total__fft_coefficient__coeff_40__attr_"imag"             NaN
# Total__fft_coefficient__coeff_40__attr_"real"             NaN
# Total__fft_coefficient__coeff_41__attr_"abs"              NaN
# Total__fft_coefficient__coeff_41__attr_"angle"            NaN
# Total__fft_coefficient__coeff_41__attr_"imag"             NaN
# Total__fft_coefficient__coeff_41__attr_"real"             NaN
# Total__fft_coefficient__coeff_42__attr_"abs"              NaN
# Total__fft_coefficient__coeff_42__attr_"angle"            NaN
# Total__fft_coefficient__coeff_42__attr_"imag"             NaN
# Total__fft_coefficient__coeff_42__attr_"real"             NaN
# Total__fft_coefficient__coeff_43__attr_"abs"              NaN
# Total__fft_coefficient__coeff_43__attr_"angle"            NaN
# Total__fft_coefficient__coeff_43__attr_"imag"             NaN
# Total__fft_coefficient__coeff_43__attr_"real"             NaN
# Total__fft_coefficient__coeff_44__attr_"abs"              NaN
# Total__fft_coefficient__coeff_44__attr_"angle"            NaN
# Total__fft_coefficient__coeff_44__attr_"imag"             NaN
# Total__fft_coefficient__coeff_44__attr_"real"             NaN
# Total__fft_coefficient__coeff_45__attr_"abs"              NaN
# Total__fft_coefficient__coeff_45__attr_"angle"            NaN
# Total__fft_coefficient__coeff_45__attr_"imag"             NaN
# Total__fft_coefficient__coeff_45__attr_"real"             NaN
# Total__fft_coefficient__coeff_46__attr_"abs"              NaN
# Total__fft_coefficient__coeff_46__attr_"angle"            NaN
# Total__fft_coefficient__coeff_46__attr_"imag"             NaN
# Total__fft_coefficient__coeff_46__attr_"real"             NaN
# Total__fft_coefficient__coeff_47__attr_"abs"              NaN
# Total__fft_coefficient__coeff_47__attr_"angle"            NaN
# Total__fft_coefficient__coeff_47__attr_"imag"             NaN
# Total__fft_coefficient__coeff_47__attr_"real"             NaN
# Total__fft_coefficient__coeff_48__attr_"abs"              NaN
# Total__fft_coefficient__coeff_48__attr_"angle"            NaN
# Total__fft_coefficient__coeff_48__attr_"imag"             NaN
# Total__fft_coefficient__coeff_48__attr_"real"             NaN
# Total__fft_coefficient__coeff_49__attr_"abs"              NaN
# Total__fft_coefficient__coeff_49__attr_"angle"            NaN
# Total__fft_coefficient__coeff_49__attr_"imag"             NaN
# Total__fft_coefficient__coeff_49__attr_"real"             NaN
# Total__fft_coefficient__coeff_4__attr_"abs"         3.252e+02
# Total__fft_coefficient__coeff_4__attr_"angle"       1.346e+02
# Total__fft_coefficient__coeff_4__attr_"imag"        2.316e+02
# Total__fft_coefficient__coeff_4__attr_"real"       -2.283e+02
# Total__fft_coefficient__coeff_50__attr_"abs"              NaN
# Total__fft_coefficient__coeff_50__attr_"angle"            NaN
# Total__fft_coefficient__coeff_50__attr_"imag"             NaN
# Total__fft_coefficient__coeff_50__attr_"real"             NaN
# Total__fft_coefficient__coeff_51__attr_"abs"              NaN
# Total__fft_coefficient__coeff_51__attr_"angle"            NaN
# Total__fft_coefficient__coeff_51__attr_"imag"             NaN
# Total__fft_coefficient__coeff_51__attr_"real"             NaN
# Total__fft_coefficient__coeff_52__attr_"abs"              NaN
# Total__fft_coefficient__coeff_52__attr_"angle"            NaN
# Total__fft_coefficient__coeff_52__attr_"imag"             NaN
# Total__fft_coefficient__coeff_52__attr_"real"             NaN
# Total__fft_coefficient__coeff_53__attr_"abs"              NaN
# Total__fft_coefficient__coeff_53__attr_"angle"            NaN
# Total__fft_coefficient__coeff_53__attr_"imag"             NaN
# Total__fft_coefficient__coeff_53__attr_"real"             NaN
# Total__fft_coefficient__coeff_54__attr_"abs"              NaN
# Total__fft_coefficient__coeff_54__attr_"angle"            NaN
# Total__fft_coefficient__coeff_54__attr_"imag"             NaN
# Total__fft_coefficient__coeff_54__attr_"real"             NaN
# Total__fft_coefficient__coeff_55__attr_"abs"              NaN
# Total__fft_coefficient__coeff_55__attr_"angle"            NaN
# Total__fft_coefficient__coeff_55__attr_"imag"             NaN
# Total__fft_coefficient__coeff_55__attr_"real"             NaN
# Total__fft_coefficient__coeff_56__attr_"abs"              NaN
# Total__fft_coefficient__coeff_56__attr_"angle"            NaN
# Total__fft_coefficient__coeff_56__attr_"imag"             NaN
# Total__fft_coefficient__coeff_56__attr_"real"             NaN
# Total__fft_coefficient__coeff_57__attr_"abs"              NaN
# Total__fft_coefficient__coeff_57__attr_"angle"            NaN
# Total__fft_coefficient__coeff_57__attr_"imag"             NaN
# Total__fft_coefficient__coeff_57__attr_"real"             NaN
# Total__fft_coefficient__coeff_58__attr_"abs"              NaN
# Total__fft_coefficient__coeff_58__attr_"angle"            NaN
# Total__fft_coefficient__coeff_58__attr_"imag"             NaN
# Total__fft_coefficient__coeff_58__attr_"real"             NaN
# Total__fft_coefficient__coeff_59__attr_"abs"              NaN
# Total__fft_coefficient__coeff_59__attr_"angle"            NaN
# Total__fft_coefficient__coeff_59__attr_"imag"             NaN
# Total__fft_coefficient__coeff_59__attr_"real"             NaN
# Total__fft_coefficient__coeff_5__attr_"abs"         1.073e+02
# Total__fft_coefficient__coeff_5__attr_"angle"      -9.302e-01
# Total__fft_coefficient__coeff_5__attr_"imag"       -1.742e+00
# Total__fft_coefficient__coeff_5__attr_"real"        1.073e+02
# Total__fft_coefficient__coeff_60__attr_"abs"              NaN
# Total__fft_coefficient__coeff_60__attr_"angle"            NaN
# Total__fft_coefficient__coeff_60__attr_"imag"             NaN
# Total__fft_coefficient__coeff_60__attr_"real"             NaN
# Total__fft_coefficient__coeff_61__attr_"abs"              NaN
# Total__fft_coefficient__coeff_61__attr_"angle"            NaN
# Total__fft_coefficient__coeff_61__attr_"imag"             NaN
# Total__fft_coefficient__coeff_61__attr_"real"             NaN
# Total__fft_coefficient__coeff_62__attr_"abs"              NaN
# Total__fft_coefficient__coeff_62__attr_"angle"            NaN
# Total__fft_coefficient__coeff_62__attr_"imag"             NaN
# Total__fft_coefficient__coeff_62__attr_"real"             NaN
# Total__fft_coefficient__coeff_63__attr_"abs"              NaN
# Total__fft_coefficient__coeff_63__attr_"angle"            NaN
# Total__fft_coefficient__coeff_63__attr_"imag"             NaN
# Total__fft_coefficient__coeff_63__attr_"real"             NaN
# Total__fft_coefficient__coeff_64__attr_"abs"              NaN
# Total__fft_coefficient__coeff_64__attr_"angle"            NaN
# Total__fft_coefficient__coeff_64__attr_"imag"             NaN
# Total__fft_coefficient__coeff_64__attr_"real"             NaN
# Total__fft_coefficient__coeff_65__attr_"abs"              NaN
# Total__fft_coefficient__coeff_65__attr_"angle"            NaN
# Total__fft_coefficient__coeff_65__attr_"imag"             NaN
# Total__fft_coefficient__coeff_65__attr_"real"             NaN
# Total__fft_coefficient__coeff_66__attr_"abs"              NaN
# Total__fft_coefficient__coeff_66__attr_"angle"            NaN
# Total__fft_coefficient__coeff_66__attr_"imag"             NaN
# Total__fft_coefficient__coeff_66__attr_"real"             NaN
# Total__fft_coefficient__coeff_67__attr_"abs"              NaN
# Total__fft_coefficient__coeff_67__attr_"angle"            NaN
# Total__fft_coefficient__coeff_67__attr_"imag"             NaN
# Total__fft_coefficient__coeff_67__attr_"real"             NaN
# Total__fft_coefficient__coeff_68__attr_"abs"              NaN
# Total__fft_coefficient__coeff_68__attr_"angle"            NaN
# Total__fft_coefficient__coeff_68__attr_"imag"             NaN
# Total__fft_coefficient__coeff_68__attr_"real"             NaN
# Total__fft_coefficient__coeff_69__attr_"abs"              NaN
# Total__fft_coefficient__coeff_69__attr_"angle"            NaN
# Total__fft_coefficient__coeff_69__attr_"imag"             NaN
# Total__fft_coefficient__coeff_69__attr_"real"             NaN
# Total__fft_coefficient__coeff_6__attr_"abs"         5.044e+02
# Total__fft_coefficient__coeff_6__attr_"angle"      -1.389e+02
# Total__fft_coefficient__coeff_6__attr_"imag"       -3.314e+02
# Total__fft_coefficient__coeff_6__attr_"real"       -3.803e+02
# Total__fft_coefficient__coeff_70__attr_"abs"              NaN
# Total__fft_coefficient__coeff_70__attr_"angle"            NaN
# Total__fft_coefficient__coeff_70__attr_"imag"             NaN
# Total__fft_coefficient__coeff_70__attr_"real"             NaN
# Total__fft_coefficient__coeff_71__attr_"abs"              NaN
# Total__fft_coefficient__coeff_71__attr_"angle"            NaN
# Total__fft_coefficient__coeff_71__attr_"imag"             NaN
# Total__fft_coefficient__coeff_71__attr_"real"             NaN
# Total__fft_coefficient__coeff_72__attr_"abs"              NaN
# Total__fft_coefficient__coeff_72__attr_"angle"            NaN
# Total__fft_coefficient__coeff_72__attr_"imag"             NaN
# Total__fft_coefficient__coeff_72__attr_"real"             NaN
# Total__fft_coefficient__coeff_73__attr_"abs"              NaN
# Total__fft_coefficient__coeff_73__attr_"angle"            NaN
# Total__fft_coefficient__coeff_73__attr_"imag"             NaN
# Total__fft_coefficient__coeff_73__attr_"real"             NaN
# Total__fft_coefficient__coeff_74__attr_"abs"              NaN
# Total__fft_coefficient__coeff_74__attr_"angle"            NaN
# Total__fft_coefficient__coeff_74__attr_"imag"             NaN
# Total__fft_coefficient__coeff_74__attr_"real"             NaN
# Total__fft_coefficient__coeff_75__attr_"abs"              NaN
# Total__fft_coefficient__coeff_75__attr_"angle"            NaN
# Total__fft_coefficient__coeff_75__attr_"imag"             NaN
# Total__fft_coefficient__coeff_75__attr_"real"             NaN
# Total__fft_coefficient__coeff_76__attr_"abs"              NaN
# Total__fft_coefficient__coeff_76__attr_"angle"            NaN
# Total__fft_coefficient__coeff_76__attr_"imag"             NaN
# Total__fft_coefficient__coeff_76__attr_"real"             NaN
# Total__fft_coefficient__coeff_77__attr_"abs"              NaN
# Total__fft_coefficient__coeff_77__attr_"angle"            NaN
# Total__fft_coefficient__coeff_77__attr_"imag"             NaN
# Total__fft_coefficient__coeff_77__attr_"real"             NaN
# Total__fft_coefficient__coeff_78__attr_"abs"              NaN
# Total__fft_coefficient__coeff_78__attr_"angle"            NaN
# Total__fft_coefficient__coeff_78__attr_"imag"             NaN
# Total__fft_coefficient__coeff_78__attr_"real"             NaN
# Total__fft_coefficient__coeff_79__attr_"abs"              NaN
# Total__fft_coefficient__coeff_79__attr_"angle"            NaN
# Total__fft_coefficient__coeff_79__attr_"imag"             NaN
# Total__fft_coefficient__coeff_79__attr_"real"             NaN
# Total__fft_coefficient__coeff_7__attr_"abs"         8.741e+02
# Total__fft_coefficient__coeff_7__attr_"angle"       4.551e+01
# Total__fft_coefficient__coeff_7__attr_"imag"        6.236e+02
# Total__fft_coefficient__coeff_7__attr_"real"        6.126e+02
# Total__fft_coefficient__coeff_80__attr_"abs"              NaN
# Total__fft_coefficient__coeff_80__attr_"angle"            NaN
# Total__fft_coefficient__coeff_80__attr_"imag"             NaN
# Total__fft_coefficient__coeff_80__attr_"real"             NaN
# Total__fft_coefficient__coeff_81__attr_"abs"              NaN
# Total__fft_coefficient__coeff_81__attr_"angle"            NaN
# Total__fft_coefficient__coeff_81__attr_"imag"             NaN
# Total__fft_coefficient__coeff_81__attr_"real"             NaN
# Total__fft_coefficient__coeff_82__attr_"abs"              NaN
# Total__fft_coefficient__coeff_82__attr_"angle"            NaN
# Total__fft_coefficient__coeff_82__attr_"imag"             NaN
# Total__fft_coefficient__coeff_82__attr_"real"             NaN
# Total__fft_coefficient__coeff_83__attr_"abs"              NaN
# Total__fft_coefficient__coeff_83__attr_"angle"            NaN
# Total__fft_coefficient__coeff_83__attr_"imag"             NaN
# Total__fft_coefficient__coeff_83__attr_"real"             NaN
# Total__fft_coefficient__coeff_84__attr_"abs"              NaN
# Total__fft_coefficient__coeff_84__attr_"angle"            NaN
# Total__fft_coefficient__coeff_84__attr_"imag"             NaN
# Total__fft_coefficient__coeff_84__attr_"real"             NaN
# Total__fft_coefficient__coeff_85__attr_"abs"              NaN
# Total__fft_coefficient__coeff_85__attr_"angle"            NaN
# Total__fft_coefficient__coeff_85__attr_"imag"             NaN
# Total__fft_coefficient__coeff_85__attr_"real"             NaN
# Total__fft_coefficient__coeff_86__attr_"abs"              NaN
# Total__fft_coefficient__coeff_86__attr_"angle"            NaN
# Total__fft_coefficient__coeff_86__attr_"imag"             NaN
# Total__fft_coefficient__coeff_86__attr_"real"             NaN
# Total__fft_coefficient__coeff_87__attr_"abs"              NaN
# Total__fft_coefficient__coeff_87__attr_"angle"            NaN
# Total__fft_coefficient__coeff_87__attr_"imag"             NaN
# Total__fft_coefficient__coeff_87__attr_"real"             NaN
# Total__fft_coefficient__coeff_88__attr_"abs"              NaN
# Total__fft_coefficient__coeff_88__attr_"angle"            NaN
# Total__fft_coefficient__coeff_88__attr_"imag"             NaN
# Total__fft_coefficient__coeff_88__attr_"real"             NaN
# Total__fft_coefficient__coeff_89__attr_"abs"              NaN
# Total__fft_coefficient__coeff_89__attr_"angle"            NaN
# Total__fft_coefficient__coeff_89__attr_"imag"             NaN
# Total__fft_coefficient__coeff_89__attr_"real"             NaN
# Total__fft_coefficient__coeff_8__attr_"abs"         1.045e+02
# Total__fft_coefficient__coeff_8__attr_"angle"       8.013e+01
# Total__fft_coefficient__coeff_8__attr_"imag"        1.029e+02
# Total__fft_coefficient__coeff_8__attr_"real"        1.791e+01
# Total__fft_coefficient__coeff_90__attr_"abs"              NaN
# Total__fft_coefficient__coeff_90__attr_"angle"            NaN
# Total__fft_coefficient__coeff_90__attr_"imag"             NaN
# Total__fft_coefficient__coeff_90__attr_"real"             NaN
# Total__fft_coefficient__coeff_91__attr_"abs"              NaN
# Total__fft_coefficient__coeff_91__attr_"angle"            NaN
# Total__fft_coefficient__coeff_91__attr_"imag"             NaN
# Total__fft_coefficient__coeff_91__attr_"real"             NaN
# Total__fft_coefficient__coeff_92__attr_"abs"              NaN
# Total__fft_coefficient__coeff_92__attr_"angle"            NaN
# Total__fft_coefficient__coeff_92__attr_"imag"             NaN
# Total__fft_coefficient__coeff_92__attr_"real"             NaN
# Total__fft_coefficient__coeff_93__attr_"abs"              NaN
# Total__fft_coefficient__coeff_93__attr_"angle"            NaN
# Total__fft_coefficient__coeff_93__attr_"imag"             NaN
# Total__fft_coefficient__coeff_93__attr_"real"             NaN
# Total__fft_coefficient__coeff_94__attr_"abs"              NaN
# Total__fft_coefficient__coeff_94__attr_"angle"            NaN
# Total__fft_coefficient__coeff_94__attr_"imag"             NaN
# Total__fft_coefficient__coeff_94__attr_"real"             NaN
# Total__fft_coefficient__coeff_95__attr_"abs"              NaN
# Total__fft_coefficient__coeff_95__attr_"angle"            NaN
# Total__fft_coefficient__coeff_95__attr_"imag"             NaN
# Total__fft_coefficient__coeff_95__attr_"real"             NaN
# Total__fft_coefficient__coeff_96__attr_"abs"              NaN
# Total__fft_coefficient__coeff_96__attr_"angle"            NaN
# Total__fft_coefficient__coeff_96__attr_"imag"             NaN
# Total__fft_coefficient__coeff_96__attr_"real"             NaN
# Total__fft_coefficient__coeff_97__attr_"abs"              NaN
# Total__fft_coefficient__coeff_97__attr_"angle"            NaN
# Total__fft_coefficient__coeff_97__attr_"imag"             NaN
# Total__fft_coefficient__coeff_97__attr_"real"             NaN
# Total__fft_coefficient__coeff_98__attr_"abs"              NaN
# Total__fft_coefficient__coeff_98__attr_"angle"            NaN
# Total__fft_coefficient__coeff_98__attr_"imag"             NaN
# Total__fft_coefficient__coeff_98__attr_"real"             NaN
# Total__fft_coefficient__coeff_99__attr_"abs"              NaN
# Total__fft_coefficient__coeff_99__attr_"angle"            NaN
# Total__fft_coefficient__coeff_99__attr_"imag"             NaN
# Total__fft_coefficient__coeff_99__attr_"real"             NaN
# Total__fft_coefficient__coeff_9__attr_"abs"         9.250e+01
# Total__fft_coefficient__coeff_9__attr_"angle"       1.755e+01
# Total__fft_coefficient__coeff_9__attr_"imag"        2.789e+01
# Total__fft_coefficient__coeff_9__attr_"real"        8.820e+01
# Total__first_location_of_maximum                    8.312e-01
# Total__first_location_of_minimum                    3.247e-01
# Total__friedrich_coefficients__m_3__r_30__coeff_0   6.380e+02
# Total__friedrich_coefficients__m_3__r_30__coeff_1  -5.395e+00
# Total__friedrich_coefficients__m_3__r_30__coeff_2   1.529e-02
# Total__friedrich_coefficients__m_3__r_30__coeff_3  -1.609e-05
# Total__has_duplicate                                0.000e+00
# Total__has_duplicate_max                            0.000e+00
# Total__has_duplicate_min                            0.000e+00
# Total__index_mass_quantile__q_0.1                   1.169e-01
# Total__index_mass_quantile__q_0.2                   2.208e-01
# Total__index_mass_quantile__q_0.3                   3.377e-01
# Total__index_mass_quantile__q_0.4                   4.286e-01
# Total__index_mass_quantile__q_0.6                   6.364e-01
# Total__index_mass_quantile__q_0.7                   7.273e-01
# Total__index_mass_quantile__q_0.8                   8.312e-01
# Total__index_mass_quantile__q_0.9                   9.091e-01
# Total__kurtosis                                    -6.092e-01
# Total__large_standard_deviation__r_0.05             1.000e+00
# Total__large_standard_deviation__r_0.1              1.000e+00
# Total__large_standard_deviation__r_0.1500000000...  1.000e+00
# Total__large_standard_deviation__r_0.2              1.000e+00
# Total__large_standard_deviation__r_0.25             0.000e+00
# Total__large_standard_deviation__r_0.3000000000...  0.000e+00
# Total__large_standard_deviation__r_0.3500000000...  0.000e+00
# Total__large_standard_deviation__r_0.4              0.000e+00
# Total__large_standard_deviation__r_0.45             0.000e+00
# Total__large_standard_deviation__r_0.5              0.000e+00
# Total__large_standard_deviation__r_0.55             0.000e+00
# Total__large_standard_deviation__r_0.6000000000...  0.000e+00
# Total__large_standard_deviation__r_0.65             0.000e+00
# Total__large_standard_deviation__r_0.7000000000...  0.000e+00
# Total__large_standard_deviation__r_0.75             0.000e+00
# Total__large_standard_deviation__r_0.8              0.000e+00
# Total__large_standard_deviation__r_0.8500000000...  0.000e+00
# Total__large_standard_deviation__r_0.9              0.000e+00
# Total__large_standard_deviation__r_0.9500000000...  0.000e+00
# Total__last_location_of_maximum                     8.442e-01
# Total__last_location_of_minimum                     3.377e-01
# Total__length                                       7.700e+01
# Total__linear_trend__attr_"intercept"               2.217e+02
# Total__linear_trend__attr_"pvalue"                  7.735e-04
# Total__linear_trend__attr_"rvalue"                  3.752e-01
# Total__linear_trend__attr_"slope"                   7.064e-01
# Total__linear_trend__attr_"stderr"                  2.015e-01
# Total__longest_strike_above_mean                    5.000e+00
# Total__longest_strike_below_mean                    9.000e+00
# Total__max_langevin_fixed_point__m_3__r_30          3.543e+02
# Total__maximum                                      3.482e+02
# Total__mean                                         2.486e+02
# Total__mean_abs_change                              4.406e+01
# Total__mean_change                                  1.093e+00
# Total__mean_second_derivative_central               4.396e-02
# Total__median                                       2.464e+02
# Total__minimum                                      1.730e+02
# Total__number_crossing_m__m_-1                      0.000e+00
# Total__number_crossing_m__m_0                       0.000e+00
# Total__number_crossing_m__m_1                       0.000e+00
# Total__number_cwt_peaks__n_1                        1.000e+01
# Total__number_cwt_peaks__n_5                        1.000e+01
# Total__number_peaks__n_1                            2.300e+01
# Total__number_peaks__n_10                           4.000e+00
# Total__number_peaks__n_3                            1.000e+01
# Total__number_peaks__n_5                            6.000e+00
# Total__number_peaks__n_50                           0.000e+00
# Total__partial_autocorrelation__lag_0               1.000e+00
# Total__partial_autocorrelation__lag_1               2.122e-01
# Total__partial_autocorrelation__lag_2              -1.577e-01
# Total__partial_autocorrelation__lag_3               2.539e-01
# Total__partial_autocorrelation__lag_4               5.095e-02
# Total__partial_autocorrelation__lag_5              -1.549e-01
# Total__partial_autocorrelation__lag_6              -8.309e-03
# Total__partial_autocorrelation__lag_7              -1.640e-01
# Total__partial_autocorrelation__lag_8               3.504e-01
# Total__partial_autocorrelation__lag_9              -1.513e-01
# Total__percentage_of_reoccurring_datapoints_to_...  0.000e+00
# Total__percentage_of_reoccurring_values_to_all_...  0.000e+00
# Total__quantile__q_0.1                              1.947e+02
# Total__quantile__q_0.2                              2.121e+02
# Total__quantile__q_0.3                              2.204e+02
# Total__quantile__q_0.4                              2.299e+02
# Total__quantile__q_0.6                              2.570e+02
# Total__quantile__q_0.7                              2.714e+02
# Total__quantile__q_0.8                              2.896e+02
# Total__quantile__q_0.9                              3.070e+02
# Total__range_count__max_0__min_1000000000000.0      0.000e+00
# Total__range_count__max_1000000000000.0__min_0      7.700e+01
# Total__range_count__max_1__min_-1                   0.000e+00
# Total__ratio_beyond_r_sigma__r_0.5                  6.883e-01
# Total__ratio_beyond_r_sigma__r_1                    3.766e-01
# Total__ratio_beyond_r_sigma__r_1.5                  1.169e-01
# Total__ratio_beyond_r_sigma__r_10                   0.000e+00
# Total__ratio_beyond_r_sigma__r_2                    3.896e-02
# Total__ratio_beyond_r_sigma__r_2.5                  0.000e+00
# Total__ratio_beyond_r_sigma__r_3                    0.000e+00
# Total__ratio_beyond_r_sigma__r_5                    0.000e+00
# Total__ratio_beyond_r_sigma__r_6                    0.000e+00
# Total__ratio_beyond_r_sigma__r_7                    0.000e+00
# Total__ratio_value_number_to_time_series_length     1.000e+00
# Total__sample_entropy                               2.329e+00
# Total__skewness                                     3.626e-01
# Total__spkt_welch_density__coeff_2                  5.993e+00
# Total__spkt_welch_density__coeff_5                  2.974e+03
# Total__spkt_welch_density__coeff_8                  2.774e+03
# Total__standard_deviation                           4.185e+01
# Total__sum_of_reoccurring_data_points               0.000e+00
# Total__sum_of_reoccurring_values                    0.000e+00
# Total__sum_values                                   1.914e+04
# Total__symmetry_looking__r_0.0                      0.000e+00
# Total__symmetry_looking__r_0.05                     1.000e+00
# Total__symmetry_looking__r_0.1                      1.000e+00
# Total__symmetry_looking__r_0.15000000000000002      1.000e+00
# Total__symmetry_looking__r_0.2                      1.000e+00
# Total__symmetry_looking__r_0.25                     1.000e+00
# Total__symmetry_looking__r_0.30000000000000004      1.000e+00
# Total__symmetry_looking__r_0.35000000000000003      1.000e+00
# Total__symmetry_looking__r_0.4                      1.000e+00
# Total__symmetry_looking__r_0.45                     1.000e+00
# Total__symmetry_looking__r_0.5                      1.000e+00
# Total__symmetry_looking__r_0.55                     1.000e+00
# Total__symmetry_looking__r_0.6000000000000001       1.000e+00
# Total__symmetry_looking__r_0.65                     1.000e+00
# Total__symmetry_looking__r_0.7000000000000001       1.000e+00
# Total__symmetry_looking__r_0.75                     1.000e+00
# Total__symmetry_looking__r_0.8                      1.000e+00
# Total__symmetry_looking__r_0.8500000000000001       1.000e+00
# Total__symmetry_looking__r_0.9                      1.000e+00
# Total__symmetry_looking__r_0.9500000000000001       1.000e+00
# Total__time_reversal_asymmetry_statistic__lag_1     1.705e+05
# Total__time_reversal_asymmetry_statistic__lag_2     3.090e+05
# Total__time_reversal_asymmetry_statistic__lag_3     4.095e+05
# Total__value_count__value_-1                        0.000e+00
# Total__value_count__value_0                         0.000e+00
# Total__value_count__value_1                         0.000e+00
# Total__variance                                     1.751e+03
# Total__variance_larger_than_standard_deviation      1.000e+00
#
# [1588 rows x 1 columns]

# %%
pwin

# %%
Series([getWindowValue(pwin[x]) for x in reversed(list(pwin.keys()))]).diff().mean()

# %%
getWindowValue(pwin[1])

# %%
sum([1 for x in pwin.values() if x is not None])

# %%
getMultiWindowValue(pwin)

# %%
timeseries = salesdata.reset_index()

# %%
from tsfresh.examples.robot_execution_failures import download_robot_execution_failures, \
    load_robot_execution_failures
download_robot_execution_failures()
timeseries, y = load_robot_execution_failures()

# %%
timeseries

# %%
y

# %% [markdown]
# # Testing

# %%
pip install fbprophet
